# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-learning-/blob/main/Day5_pyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = "sheema"
print(A[1])
# Out:
# h

# %%
A = "my name is shabana"
print(A[1:])
# Out:
# y name is shabana

# %%
A = "my name is shabana"
B = len(A)
print(B)
# Out:
# 18

# %%
A = "my name is shabana"
print(A[-16:])
# Out:
#  name is shabana

# %%
A= input("enter ur name")
B = len(A)
print(B)
# Out:
# enter ur nameDhabana
# 7

# %%
a = input("enter ur name")
B = a.count('$')
print(B)
# Out:
# enter ur name$heema
# 1

# %%
#Reverse a string.
a = input("enter ur name")
print(a[::-1])
# Out:
# enter ur namesheema
# ameehs

# %%
#Check whether a number is positive, negative, or zero.
num = float(input("enter any number"))
if(num == 0):
  print("the numbrer is zero")
elif(num > 0):
  print("the number is postive")
elif(num < 0):
  print("the numer is negative")
else:
  print("not defined")
# Out:
# enter any number90.00
# the number is postive

# %%
#Check whether a number is even or odd.
s = int(input("enter a number"))
if(s % 2 == 0):
  print("the numbrer is even")
else:
  print("the number is odd")
# Out:
# enter a number17777
# the number is odd

# %%
#Check whether a person is eligible to vote based on age.
age = int(input("enter ur age"))
if age >= 18:
   print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# enter ur age35
# eligible to vote
