# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-learning-/blob/main/Day7_py2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Mini Project: ATM System
Create these functions:
check_balance(balance)
deposit(balance, amount)
withdraw(balance, amount)
Initial balance:
balance = 1000
Requirements:
check_balance(balance) → returns the current balance.
deposit(balance, amount) → adds money and returns the updated balance.
withdraw(balance, amount) →
If amount <= balance, subtract and return the updated balance.
Otherwise, return "Insufficient Balance".
🌟 Bonus Challenge

Create one more function:
transfer(balance, amount)
if enough balance exists, deduct the amount and return the new balance.
Otherwise, return "Transfer Failed"."""

def check_balance(balance):
  return balance
def deposit(balance, amount):
 return balance + amount
def withdraw(balance,amount):
 if balance >= amount:
  return balance - amount
 else:
   return("insufficient balance")
def transfer(balance,amount):
  if balance>=amount:
    new_balance = balance - amount
    return(new_balance)
  else:
    return "transfer failed"
balance = 1000
print(check_balance(balance))
print(deposit(balance, 400))
print(withdraw(balance, 900))
print(transfer(balance,800))
# Out:
# 1000
# 1400
# 100
# 200
