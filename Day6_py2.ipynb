# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-learning-/blob/main/Day6_py2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Mini Project Challenge
Creats:
student_names = ["Rahul", "Priya", "Arjun", "Sneha", "Kiran"]
fee_amounts = [50000, 60000, 45000, 55000, 50000]
branches = {"CSE", "ECE", "EEE", "CSE", "IT"}
Print:
Total fee collected
Number of students
Unique branches"""
student_names = ["Rahul", "Priya", "Arjun", "Sneha", "Kiran"]
fee_amounts = [50000, 60000, 45000, 55000, 50000]
branches = {"CSE", "ECE", "EEE", "CSE", "IT"}
print(f"Total_fee_collected:  {sum(fee_amounts)}")
print(f"Number_of_students: {len(student_names)}")

print(f"Unique branches: {branches}")
# Out:
# Total_fee_collected:  260000
# Number_of_students: 5
# Unique branches: {'EEE', 'IT', 'ECE', 'CSE'}
