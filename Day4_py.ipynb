# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-learning-/blob/main/Day4_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Student Scholarship Eligibility Checker
Write a Python program that:
Takes a student's name as input.
Takes the student's percentage as input.
Displays the scholarship status based on the percentage."""
Stu_name = input("enter ur name")
Stu_percentage = int(input("enter ur percentage"))
if(Stu_percentage >= 90 and Stu_percentage <= 100):
    print("full scholarship")
elif(Stu_percentage >= 75 and Stu_percentage < 90):
    print(" partial scholarship")
elif(Stu_percentage < 75):
    print("no scholarship")
else:
   print("not defined")
# Out:
# enter ur nameSheema
# enter ur percentage65
# no scholarship
