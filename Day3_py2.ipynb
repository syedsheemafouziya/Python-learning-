# %% [markdown]
# <a href="https://colab.research.google.com/github/syedsheemafouziya/Python-learning-/blob/main/Day3_py2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Create a program that:
Takes Student Name
Takes Roll Number
Takes Tuition Fee
Takes Exam Fee
Takes Scholarship Amount
Calculates:
total_fee = tuition_fee + exam_fee
payable_fee = total_fee - scholarship_amount
Prints a neat receipt:"""
Stu_name = input("enter your name please: ")
Roll_number = int(input(" enter your roll number please: "))
Tuition_fee = int(input("enter your tution fee: "))
Exam_fee = int(input("enter your exam fee: "))
Scholarship_amount = int(input("enter ur scholarship fee: "))
Total_fee = Tuition_fee + Exam_fee
Payable_fee = Total_fee - Scholarship_amount
print(f"==== COLLEGE FEE RECEIPT =====\n student name: {Stu_name} \n roll number is : {Roll_number} \n tution fee : {Tuition_fee} \n exam fee : {Exam_fee} \n scholarship fee is : {Scholarship_amount} \n total fee : {Total_fee} \n===============================")
# Out:
# enter your name please: Sheema
#  enter your roll number please: 18
# enter your tution fee: 43000
# enter your exam fee: 1500
# enter ur scholarship fee: 43000
# ==== COLLEGE FEE RECEIPT =====
#  student name: Sheema
#  roll number is : 18
#  tution fee : 43000
#  exam fee : 1500
#  scholarship fee is : 43000
#  total fee : 44500
# ...
